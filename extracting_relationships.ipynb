# %%
import pandas as pd

movies_df = pd.read_csv("Barbieverse-Movies.csv")
characters_df = pd.read_csv("Barbieverse-Characters.csv")

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import spacy
from spacy import displacy

# %%
# Combine datasets
combined_df = pd.concat([movies_df, characters_df], axis=1)

# %%
#Ensure that Spacy's English model are installed
# !python3 -m spacy download en_core_web_sm
# Out:
# /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 75.8 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (58.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/phathaphonsawettaboot/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
print(combined_df)
# Out:
#      No. Movie                            Movie Title Release Date  \
# 0          1.0               Barbie in the Nutcracker   02/10/2001
# 1          2.0                     Barbie as Rapunzel   01/10/2002
# 2          3.0                    Barbie of Swan Lake   30/09/2003
# 3          4.0  Barbie as The Princess and the Pauper   28/09/2004
# 4          5.0                      Barbie Fairytopia   08/03/2005
# ..         ...                                    ...          ...
# 882        NaN                                    NaN          NaN
# 883        NaN                                    NaN          NaN
# 884        NaN                                    NaN          NaN
# 885        NaN                                    NaN          NaN
# 886        NaN                                    NaN          NaN
#
#                       Era                           Ending Credits Quote  \
# 0    Adaptations &Testing                                      No quote.
# 1    Adaptations &Testing   "Love and imagination can change the world."
# 2    Adaptations &Testing                "You're braver than you think."
# 3    Adaptations &Testing                             "Live your dream."
# 4    Adaptations &Testing  "What makes you different makes you special."
# ..                    ...                                            ...
# 882                   NaN                                            NaN
# 883                   NaN                                            NaN
# 884                   NaN                                            NaN
# 885                   NaN                                            NaN
# 886                   NaN                                            NaN
#
#                                           Poster Image  No.  Movie  \
# 0    https://static.wikia.nocookie.net/barbie-movie...           1
# 1    https://static.wikia.nocookie.net/barbie-movie...           1
# 2    https://static.wikia.nocookie.net/barbie-movie...           1
# 3    https://static.wikia.nocookie.net/barbie-movie...           1
# 4    https://static.wikia.nocookie.net/barbie-movie...           1
# ..                                                 ...         ...
# 882                                                NaN          42
# 883                                                NaN          42
# 884                                                NaN          42
# 885                                                NaN          42
# 886                                                NaN          42
#
#      No. Character     Character Name Barbie Cast     Skin Tone        Eyes  \
# 0                1             Barbie      Barbie  Light Medium        Blue
# 1                2  Aunt Drosselmayer         NaN         Light       Green
# 2                3      Captain Candy         NaN   Medium Deep        Deep
# 3                4              Clara      Barbie  Light Medium        Blue
# 4                5     Flower Faeries         NaN  Light Medium  Multicolor
# ..             ...                ...         ...           ...         ...
# 882            738      Scary Monster         NaN           NaN         NaN
# 883            739              Tammy         NaN  Light Medium       Brown
# 884            740         Tough Jock         NaN           NaN         NaN
# 885            741       Trucker Pete         NaN         Light       Green
# 886            742  Zincenzio Dracula         NaN           NaN         NaN
#
#            Hair  Gender          Race     Speaking Voice Singing Voice
# 0        Blonde  Female         Human     Kelly Sheridan           NaN
# 1         Brown  Female         Human      Kathleen Barr           NaN
# 2         Brown    Male         Human  Ian James Corlett           NaN
# 3        Blonde  Female         Human     Kelly Sheridan           NaN
# 4    Multicolor  Female  Flower Fairy    Shona Galbraith           NaN
# ..          ...     ...           ...                ...           ...
# 882         NaN    Male           NaN       Ritesh Rajan           NaN
# 883  Dark Brown  Female         Human        Kirsten Day           NaN
# 884         NaN    Male         Human       Ritesh Rajan           NaN
# 885     Redhair    Male         Human        Bill Rogers           NaN
# 886         NaN     NaN           NaN          Greg Chun           NaN
#
# [887 rows x 17 columns]

# %%
cleaned_df = combined_df.dropna(subset=['Skin Tone', 'Hair', 'Eyes'])

# %%
cleaned_df.isnull().sum()
# Out:
# No. Movie               593
# Movie Title             593
# Release Date            593
# Era                     593
# Ending Credits Quote    593
# Poster Image            593
# No.  Movie                0
# No. Character             0
# Character Name            0
# Barbie Cast             488
# Skin Tone                 0
# Eyes                      0
# Hair                      0
# Gender                    0
# Race                      0
# Speaking Voice            4
# Singing Voice           602
# dtype: int64

# %%
cleaned_second_df = cleaned_df.iloc[:, 6:-3]

# %%
cleaned_second_df.isnull().sum()
# Out:
# No.  Movie          0
# No. Character       0
# Character Name      0
# Barbie Cast       488
# Skin Tone           0
# Eyes                0
# Hair                0
# Gender              0
# dtype: int64

# %%
delete_no_char = cleaned_second_df.columns[1]
delete_second_char = cleaned_second_df.columns[2]
cleaned_third_df = cleaned_second_df.drop(columns=[delete_no_char, delete_second_char])

# %%
cleaned_third_df.isnull().sum()
# Out:
# No.  Movie       0
# Barbie Cast    488
# Skin Tone        0
# Eyes             0
# Hair             0
# Gender           0
# dtype: int64

# %%
# Create the graph
G = nx.Graph()

# %%
# Function to add edges between all combinations of values in a list
def add_edges(graph, values):
    for i in range(len(values)):
        for j in range(i+1, len(values)):
            if graph.has_edge(values[i], values[j]):
                graph[values[i]][values[j]]['weight'] += 1
            else:
                graph.add_edge(values[i], values[j], weight=1)

# %%
# Iterate over rows and add edges
for index, row in cleaned_third_df.iterrows():
    row_values = row.dropna().astype(str).unique()
    add_edges(G, row_values)

# %%
# Drawing the graph
plt.figure(figsize=(12, 12))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, pos, with_labels=True, node_size=[v * 10 for v in dict(G.degree()).values()], font_size=8)
plt.show()

# %%
# Save the figure
plt.savefig("network_graph.png", format="png", dpi=300)

# %%
from pyvis.network import Network

# Initialize Pyvis Network
net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white")
net.toggle_physics(False)

# Calculate node sizes based on degree
degree_dict = dict(G.degree())

# Scale factor for positions
scale = 1000  # Adjust this value as needed

# Add nodes with adjusted positions, sizes, and larger font for labels
for node, position in pos.items():
    size = degree_dict[node] * 0.5  # Adjust size factor as needed
    label = f"{node} ({degree_dict[node]})"
    net.add_node(node, label=label, x=position[0]*scale, y=position[1]*scale, size=size, font_size=50)

# Add edges
for edge in G.edges():
    net.add_edge(edge[0], edge[1])

# Generate and display the network
net.show("barbieverse.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# barbieverse.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="barbieverse.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
degree_centrality = nx.degree_centrality(G)
degree_dict
# Out:
# {'1': 25,
#  'Barbie': 51,
#  'Light Medium': 97,
#  'Blue': 82,
#  'Blonde': 60,
#  'Female': 111,
#  'Light': 78,
#  'Green': 69,
#  'Brown': 98,
#  'Medium Deep': 20,
#  'Deep': 32,
#  'Male': 85,
#  'Multicolor': 3,
#  'Tommy': 10,
#  'Silver': 9,
#  'Kelly / Chelsea': 21,
#  'Light Brown': 35,
#  'Gray': 42,
#  'White': 17,
#  'Black/Green': 3,
#  'Purple': 40,
#  'Ken': 33,
#  'Medium Brown': 5,
#  'Dark Blue': 4,
#  'Medium': 49,
#  'Dark Brown': 30,
#  '2': 19,
#  'Light Green': 14,
#  'Dark': 39,
#  'Redhair': 26,
#  '3': 23,
#  'Teresa': 13,
#  'Light Gray': 15,
#  'Deep Blue': 15,
#  'Pink': 28,
#  'Deep Brown': 10,
#  '4': 15,
#  '5': 18,
#  'Orange': 13,
#  'Platinum Blonde': 8,
#  'Black': 9,
#  'Amber': 5,
#  'Strawberry Blonde': 5,
#  '6': 22,
#  'Dark Gray': 17,
#  'Hazel': 7,
#  'Yellow/Blue': 4,
#  '7': 16,
#  'Blue/Pink': 4,
#  '8': 20,
#  'Courtney': 5,
#  'Light Blue': 17,
#  'Dark Blonde': 9,
#  '9': 22,
#  'White/Gray': 3,
#  'Light Teal': 7,
#  'Light Blonde': 12,
#  '10': 20,
#  'Light Purple': 8,
#  '11': 16,
#  'Red': 7,
#  '12': 17,
#  'Blonde/Pink': 10,
#  'Teal': 15,
#  '13': 17,
#  'Stacie': 18,
#  '14': 16,
#  '15': 12,
#  '16': 13,
#  '17': 21,
#  'Brown/Blue': 7,
#  'Brown/Purple': 9,
#  'Blonde/Blue': 9,
#  'Yellow': 13,
#  'Brown/Pink': 7,
#  '18': 21,
#  'Raquelle': 6,
#  '19': 16,
#  '20': 15,
#  '21': 14,
#  'Skipper': 16,
#  '22': 17,
#  '23': 13,
#  '24': 16,
#  'Dark/Gray': 4,
#  '25': 18,
#  '26': 17,
#  '27': 17,
#  '28': 18,
#  'Gray/White': 4,
#  'Purple and Yellow': 5,
#  'Purple/Yellow': 5,
#  '29': 14,
#  'Purple/Orange': 4,
#  'Blue/Yellow': 4,
#  '30': 24,
#  'Red/Orange': 4,
#  'Dark Brown/Pink': 4,
#  'Dark Red': 6,
#  'Pale Blonde': 4,
#  'Blue/Silver': 4,
#  '31': 18,
#  'Christie': 5,
#  '32': 16,
#  'Violet/Pink': 4,
#  'Light Gray/White': 4,
#  '33': 17,
#  '34': 16,
#  '35': 20,
#  'Red/Cyan': 4,
#  'Pink/Blue': 4,
#  '36': 14,
#  '37': 23,
#  '38': 21,
#  '39': 23,
#  'Barbie Brooklyn': 8,
#  'Dark/White': 4,
#  '40': 26,
#  'Rainbow': 7,
#  '41': 18,
#  '42': 26,
#  'Dark/Blue': 4,
#  'Dark Pink': 4,
#  'Brown/Blonde': 4}

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
degree_df.sort_values('centrality', ascending= False)[0:14].plot(kind="bar")
# Out:
# <Axes: >

# %%
betweenness_dict = nx.betweenness_centrality(G)
degree_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
degree_df.sort_values('centrality', ascending=False)[0:14].plot(kind="bar")
# Out:
# <Axes: >

# %%
closeness_dict = nx.closeness_centrality(G)

closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
closeness_df.sort_values('centrality', ascending=False)[0:14].plot(kind="bar")
# Out:
# <Axes: >

# %%
nx.set_node_attributes(G, degree_dict, 'degree_centrality')
nx.set_node_attributes(G, betweenness_dict, 'betwenness_centrality')
nx.set_node_attributes(G, closeness_dict, 'closeness_centrality')

# %%
import community as community_louvain

# %%
communities = community_louvain.best_partition(G)

# %%
communities
# Out:
# {'1': 0,
#  'Barbie': 1,
#  'Light Medium': 1,
#  'Blue': 1,
#  'Blonde': 1,
#  'Female': 1,
#  'Light': 2,
#  'Green': 2,
#  'Brown': 0,
#  'Medium Deep': 0,
#  'Deep': 0,
#  'Male': 0,
#  'Multicolor': 0,
#  'Tommy': 0,
#  'Silver': 0,
#  'Kelly / Chelsea': 1,
#  'Light Brown': 1,
#  'Gray': 0,
#  'White': 0,
#  'Black/Green': 0,
#  'Purple': 2,
#  'Ken': 0,
#  'Medium Brown': 0,
#  'Dark Blue': 0,
#  'Medium': 0,
#  'Dark Brown': 1,
#  '2': 1,
#  'Light Green': 1,
#  'Dark': 0,
#  'Redhair': 2,
#  '3': 0,
#  'Teresa': 0,
#  'Light Gray': 0,
#  'Deep Blue': 1,
#  'Pink': 1,
#  'Deep Brown': 0,
#  '4': 0,
#  '5': 2,
#  'Orange': 2,
#  'Platinum Blonde': 2,
#  'Black': 2,
#  'Amber': 2,
#  'Strawberry Blonde': 2,
#  '6': 2,
#  'Dark Gray': 0,
#  'Hazel': 2,
#  'Yellow/Blue': 0,
#  '7': 2,
#  'Blue/Pink': 2,
#  '8': 2,
#  'Courtney': 2,
#  'Light Blue': 1,
#  'Dark Blonde': 1,
#  '9': 1,
#  'White/Gray': 0,
#  'Light Teal': 1,
#  'Light Blonde': 1,
#  '10': 2,
#  'Light Purple': 2,
#  '11': 1,
#  'Red': 1,
#  '12': 1,
#  'Blonde/Pink': 1,
#  'Teal': 0,
#  '13': 0,
#  'Stacie': 1,
#  '14': 0,
#  '15': 1,
#  '16': 0,
#  '17': 1,
#  'Brown/Blue': 2,
#  'Brown/Purple': 1,
#  'Blonde/Blue': 2,
#  'Yellow': 2,
#  'Brown/Pink': 0,
#  '18': 1,
#  'Raquelle': 2,
#  '19': 0,
#  '20': 1,
#  '21': 1,
#  'Skipper': 1,
#  '22': 1,
#  '23': 0,
#  '24': 0,
#  'Dark/Gray': 0,
#  '25': 0,
#  '26': 1,
#  '27': 1,
#  '28': 2,
#  'Gray/White': 2,
#  'Purple and Yellow': 2,
#  'Purple/Yellow': 2,
#  '29': 1,
#  'Purple/Orange': 1,
#  'Blue/Yellow': 1,
#  '30': 2,
#  'Red/Orange': 2,
#  'Dark Brown/Pink': 2,
#  'Dark Red': 1,
#  'Pale Blonde': 2,
#  'Blue/Silver': 2,
#  '31': 1,
#  'Christie': 0,
#  '32': 0,
#  'Violet/Pink': 2,
#  'Light Gray/White': 0,
#  '33': 0,
#  '34': 0,
#  '35': 2,
#  'Red/Cyan': 2,
#  'Pink/Blue': 2,
#  '36': 1,
#  '37': 0,
#  '38': 1,
#  '39': 1,
#  'Barbie Brooklyn': 0,
#  'Dark/White': 0,
#  '40': 1,
#  'Rainbow': 2,
#  '41': 0,
#  '42': 0,
#  'Dark/Blue': 0,
#  'Dark Pink': 0,
#  'Brown/Blonde': 0}

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
# Add community information as an attribute to the nodes
nx.set_node_attributes(G, communities, 'community')

# Create the Pyvis network
com_net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white")
com_net.toggle_physics(False)

# Generate positions using NetworkX's kamada_kawai_layout
pos = nx.kamada_kawai_layout(G)
scale = 1000  # Adjust this value based on your layout preference

# Add nodes with adjusted positions and community-based colors
for node, position in pos.items():
    size = degree_dict[node] * 1  # Adjust size as needed
    detailed_info = f"Node: {node}\nDegree: {degree_dict[node]}\nCommunity: {communities[node]}"
    # Add more information from the DataFrame if needed
    com_net.add_node(node, title=detailed_info, x=position[0]*scale, y=position[1]*scale, size=size, group=communities[node])

# Add edges
for edge in G.edges():
    com_net.add_edge(edge[0], edge[1])

# Visualize the network
com_net.show("barbie_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# barbie_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="barbie_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Add community information as an attribute to the nodes
nx.set_node_attributes(G, communities, 'community')

# Create the Pyvis network
com_net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white")
com_net.toggle_physics(False)

# Generate positions using NetworkX's kamada_kawai_layout
pos = nx.kamada_kawai_layout(G)
scale = 1000  # Adjust this value based on your layout preference

# Add nodes with adjusted positions and community-based colors
for node, position in pos.items():
    size = degree_dict[node] * 1
    # Format tooltip text to resemble a table
    detailed_info = (
        f"<b>Node:</b> {node}<br>"
        f"<b>Degree:</b> {degree_dict[node]}<br>"
        f"<b>Community:</b> {communities[node]}"
    )
    com_net.add_node(node, title=detailed_info, x=position[0]*scale, y=position[1]*scale, size=size, group=communities[node])

# Add edges
for edge in G.edges():
    com_net.add_edge(edge[0], edge[1])

# Visualize the network
com_net.show("barbie_communities2.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# barbie_communities2.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="barbie_communities2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Create a DataFrame for the table
table_df = pd.DataFrame({
    'Node': list(G.nodes),
    'Degree': [degree_dict[node] for node in G.nodes],
    'Community': [communities[node] for node in G.nodes]
})

# Display the DataFrame as a table
table_df
# Out:
#              Node  Degree  Community
# 0               1      25          0
# 1          Barbie      51          1
# 2    Light Medium      97          1
# 3            Blue      82          1
# 4          Blonde      60          1
# ..            ...     ...        ...
# 119            41      18          0
# 120            42      26          0
# 121     Dark/Blue       4          0
# 122     Dark Pink       4          0
# 123  Brown/Blonde       4          0
#
# [124 rows x 3 columns]

# %%
# Sort the DataFrame first by 'Community' and then by 'Node', both in ascending order
sorted_table_df = table_df.sort_values(by=['Community', 'Node'], ascending=[True, True])

# Save the sorted DataFrame to a CSV file
sorted_table_df.to_csv("sorted_node_community_table.csv", index=False)

# %%
summary_data = []

for column in cleaned_third_df.columns:
    # Ensure all data is in string format
    cleaned_third_df[column] = cleaned_third_df[column].astype(str)

    # Group and count occurrences
    grouped_data = cleaned_third_df.groupby(column).size().reset_index(name='Count')
    grouped_data.rename(columns={column: 'Value'}, inplace=True)
    grouped_data['Column'] = column
    summary_data.append(grouped_data)

# Combine all DataFrames into one
summary_df = pd.concat(summary_data)

# Save the summary DataFrame to a CSV file
summary_df.to_csv("grouped_data_summary.csv", index=False)

# %%
csv1_df = pd.read_csv("sorted_node_community_table.csv")
csv2_df = pd.read_csv("grouped_data_summary.csv")

# %%
combined_df = pd.merge(csv1_df, csv2_df, left_on=['Node', 'Degree'], right_on=['Value', 'Count'], how='outer')

# %%
combined_df.to_csv("combined_data.csv", index=False)
